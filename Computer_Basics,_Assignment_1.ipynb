# %% [markdown]
# <a href="https://colab.research.google.com/github/pratyushniu21267/Core-Java-with-DSA/blob/main/Computer_Basics%2C_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. What is a Computer?
#
# A computer is an electrical device that processes data using a set of
# instructions (programs) to execute tasks, solve problems, and produce
# results.  It uses both hardware (physical components) and software
# (programs/apps) to work. Computer processes data in the machine language.

# %% [markdown]
# 2. What is RAM?
#
# RAM (Random Access Memory) is a type of volatile memory in a computer that temporarily maintains data and instructions that the CPU (Central Processing Unit) may quickly access while doing tasks.  Unlike hard drives (such as HDDs or SSDs), RAM loses all data when the system is turned off.

# %% [markdown]
# 3. Where is data stored in a computer?
#
# ![Screenshot 2025-03-18 at 3.19.56 PM.png](data:image/png;base64,...)
#
# Data in a computer is stored across multiple types of memory and storage devices, each serving a specific purpose.

# %% [markdown]
# 4. What is that input device used to type text and numbers on a document in the computer system?
#
# Keyboard

# %% [markdown]
# 5. What is that input device used to type text and numbers on a document in the computer system?
#
# Output devices are physical components that display, generate, or send processed data from a computer to users or other systems.  They transform digital data into human-readable representations (such as text, pictures, and audio) or physical outputs.

# %% [markdown]
# 6. Which is the input device that allows a user to move the cursor or pointer on the screen?
#
# Mouse

# %% [markdown]
# 7. Which language is directly understood by the computer without a translation program?
#
# Binary Code

# %% [markdown]
# 8. What are Input devices?
#
# Input devices are physical components that enable people to submit data, requests, or instructions to computers.  They serve as a link between humans and machines, translating physical movements (such as typing, clicking, or speaking) into digital signals that computers can understand.
